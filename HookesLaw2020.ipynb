# %% [markdown]
# # Method 1:  Determine k for spring 1 and 2

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([100,120,140,160,180,200])/1000
x1 = np.array([33,39.5,46,52.5,59,65.5])/100
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Small k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 3.02 N/m
# Error in slope = 0.04 N/m
# Goodness of fit = 0.00

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([100,120,140,160,180,200])/1000
x1 = np.array([9,10.5,12,14,15.5,17])/100
errm = np.array([1,1,1,1,1,1])/1000

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Large k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 12.01 N/m
# Error in slope = 0.14 N/m
# Goodness of fit = 12.90

# %% [markdown]
# # Method 2:  Determine k for spring 1 and 2

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([.99,.96,.9,.888,.850,.81])**2
x1 = np.array([300,280,260,240,220,200])/1000
errm = np.array([.0396,.0387,.0324,.0354,.034,.0324])

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1,errm,'Large k spring','m(kg)','T^2(s^2)','N/m')
# Out:
# Slope = 3.23 N/m
# Error in slope = 0.43 N/m
# Goodness of fit = 1.43

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([1.41,1.26,1.19,1.07,.95,.81])**2
x1 = np.array([150,130,110,90,70,50])/1000
errm = np.array([.0564,.0504,.0476,.0423,.038,.0324])

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1,errm,'Small k spring','m(kg)','T^2(s^2)','N/m')
# Out:
# Slope = 13.08 N/m
# Error in slope = 0.52 N/m
# Goodness of fit = 4.73
